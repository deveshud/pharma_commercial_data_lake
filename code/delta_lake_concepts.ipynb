# %%
spark.sql("""
DESCRIBE HISTORY cdl.bronze.call_activity_bronze
""").display()

# %%
# %sql
select * from cdl.bronze.call_activity_bronze
version as of 22;

# %%
# %sql
select count(*) from cdl.bronze.call_activity_bronze;

# %%
# %sql
select count(*) from cdl.bronze.call_activity_bronze
version as of 23;

# %%
# %sql
describe history cdl.bronze.call_activity_bronze;

# %%
# %sql 
RESTORE TABLE cdl.bronze.call_activity_bronze
VERSION AS OF 23;
