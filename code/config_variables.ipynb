# %%
catalog_name = "cdl"
bronze_schema = "bronze"
volume_name = "landing_files"

source_base_path = f"/Volumes/{catalog_name}/{bronze_schema}/{volume_name}"

destination_schema = "bronze"

destination_storage_account = "datalakedevesh"
destination_container = "destination-cdl"
destination_base_path = f"abfss://{destination_container}@{destination_storage_account}.dfs.core.windows.net/{destination_schema}/"

# %%
display(dbutils.fs.ls(source_base_path))
