-- %%
select target_table_name,source_file_date,source_file_name,row_count,write_mode from cdl.audit.ingestion_load_log
where load_status = "success"
order by source_file_date desc;

select * from cdl.gold.brand_weekly_performance;

select * from cdl.gold.vw_hcp_engagement;

USE CATALOG cdl; 
SHOW VIEWs IN gold;
